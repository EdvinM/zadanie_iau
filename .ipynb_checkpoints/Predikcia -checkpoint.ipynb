# %% [markdown]
# # Predikcia

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.stats.api as sms
from sklearn.pipeline import Pipeline

from sklearn.metrics import precision_score
import matplotlib.pyplot as plt

# %%
pd.options.display.width = None
pd.options.display.max_columns = None

# %%
from Models import CombineDatasets as d1
from Models import DecodeJSONColumn as d2
from Models import ColumnDropper as d3
from Models import BinaryEncoder as d4
from Models import ClassFixer as d5
from Models import FixDates as d6
from Models import ComputeCurYear as d7
from Models import Replacer as d8
from Models import FillMeasuredColumns as d9
from Models import CountMeasuredHormones as d10
from Models import FillNanNumeric as d11
from Models import PredictNanNumeric as d12
from Models import Classifier as d13
from Models import QuantileReplacer as d14
from Models import Fitter as d15
from Models import ColumnSelector as d16
from Models import Normalizer as d17
from Models import OneHotEncoder as d18

# %%
bool_columns = [
    'FTI measured',
    'I131 treatment',
    'T3 measured',
    'goitre',
    'lithium',
    'on thyroxine',
    'pregnant',
    'tumor',
    'query on thyroxine',
    'thyroid surgery',
    'TSH measured',
    'query hyperthyroid',
    'TT4 measured',
    'on antithyroid medication',
    'sick',
    'T4U measured',
    'psych',
    'query hypothyroid'
]

# %% [markdown]
# # Zadefinovanie pipelinov pomocou ktorych budeme spracovavat data

# %%
from sklearn.pipeline import FeatureUnion

# %%
# Transformacna pipelina, ktora robi transformacie nad zadanymi datasetmi
transf_ppl = Pipeline([
    ('combination', d1.CombineDatasets()),
    ('json_decode', d2.DecodeJSONColumn('medical_info')),
    ('drop_columns', d3.ColumnDropper(['hypopituitary', 'TBG measured', 'TBG'])),
    ('binary_fixer', d4.BinaryEncoder(bool_columns)),
    ('class_fix', d5.ClassFixer()),
    ('fix_dates', d6.FixDates()),
    ('compute_cur_year', d7.ComputeCurYear()),
    ('fti_question_mark_to_nan2', d8.Replacer(['FTI'], '?.4', float('nan'), str)),
    ('fti_question_mark_to_nan', d8.Replacer(['FTI'], '?', float('nan'), str)),
    ('fti_question_mark_to_nan1', d8.Replacer(['FTI'], np.nan, float('nan'), str)),
    ('fti_question_mark_to_nan3', d8.Replacer(['FTI'], np.nan, float('nan'), float)),
    ('fill_measured_columns', d9.FillMeasuredColumns()),
    ('count_measured', d10.CountMeasuredHormones('measured_hormones'))
])
    
# Pipelina ktora doplna chybajuce hodnoty
pred_ppl = Pipeline([
    # Fill hormony
    ('fitter', d15.Fitter()),
    ('fill_tt4', d11.FillNanNumeric('mean', 'TT4')),
    ('fill_tsh', d11.FillNanNumeric('median', 'TSH')),
    ('predicted_t3', d12.PredictNanNumeric('T3', ['TT4', 'TSH'])),
    ('predicted_t4u', d12.PredictNanNumeric('T4U', ['TT4', 'TSH'])),
    ('predicted_fti', d12.PredictNanNumeric('FTI', ['TT4', 'TSH', 'T4U'])),
    
    # Fill pregnant
    ('pregnant_predict', d13.Classifier('pregnant', ['T3', 'T4U', 'TT4'])),
    
    # Fill other variables
    ('fill_tumor', d11.FillNanNumeric('median', 'tumor')),
    ('fill_lithium', d11.FillNanNumeric('mean', 'lithium')),
    ('fill_on_thyroxine', d11.FillNanNumeric('mean', 'on thyroxine')),
    ('fill_goitre', d11.FillNanNumeric('most_frequent', 'goitre')),
    ('fill_age', d11.FillNanNumeric('most_frequent', 'age')),
    ('fill_q_on_thyroxine', d11.FillNanNumeric('mean', 'query on thyroxine')),
    
    #Normalize
#     ('normalize_t3', d17.Normalizer('T3', 'log')),
#     ('normalize_t4u', d17.Normalizer('T4U', 'log')),
    ('normalize_tsh', d17.Normalizer('TSH', 'log')),
    ('normalize_tt4', d17.Normalizer('TT4', 'log')),
    ('normalize_fti', d17.Normalizer('FTI', 'log')),

    #Replace outlier
    ('replace_t3', d14.QuantileReplacer('T3')),
    ('replace_age', d14.QuantileReplacer('age')),
    ('replace_t4u', d14.QuantileReplacer('T4U')),
    ('replace_tsh', d14.QuantileReplacer('TSH')),
    ('replace_tt4', d14.QuantileReplacer('TT4')),
    ('replace_fti', d14.QuantileReplacer('FTI')),
    ('one_hot_encoder_sex', d18.OneHotEncoder('sex')),
])

# %% [markdown]
# ## Nacitanie trenovacich dat a ich spracovanie

# %%
data_personal_train = pd.read_csv("data/personal_train.csv")
data_other_train = pd.read_csv("data/other_train.csv")

# %%
data_train = transf_ppl.fit_transform(data_personal_train, data_other_train)
data_train = pred_ppl.fit_transform(data_train, data_train)

# %% [markdown]
# ## Nacitanie validacnych dat a ich spracovanie

# %%
data_personal_valid = pd.read_csv("data/personal_valid.csv")
data_other_valid = pd.read_csv("data/other_valid.csv")

# %%
data_valid = transf_ppl.fit_transform(data_personal_valid, data_other_valid)

# %%
mdl_valid = pred_ppl.fit(data_train)
data_valid = mdl_valid.transform(data_valid)

# %% [markdown]
# ## Nacitanie testovacich dat a ich spracovanie

# %%
data_personal_test = pd.read_csv("data/personal_test.csv")
data_other_test = pd.read_csv("data/other_test.csv")

# %%
data_test = transf_ppl.fit_transform(data_personal_test, data_other_test)

# %%
mdl_test = pred_ppl.fit(data_train)
data_test = mdl_test.transform(data_test)

# %%
data_test['class'] = '?'

# %% [markdown]
# ----

# %% [markdown]
# ## Rozhodovacie pravidlá

# %%
data_train.groupby('class').count()
# Out:
#                            Unnamed: 0_x  name  address   age   sex  \
# class
# decreased binding protein             9     9        9     9     9
# increased binding protein            97    97       97    97    97
# negative                           2131  2131     2131  2131  2131
#
#                            date_of_birth  FTI measured  I131 treatment    T3  \
# class
# decreased binding protein              9             9               9     9
# increased binding protein             97            97              97    97
# negative                            2130          2131            2131  2131
#
#                            T3 measured   T4U   TSH   TT4  Unnamed: 0_y  \
# class
# decreased binding protein            9     9     9     9             9
# increased binding protein           97    97    97    97            97
# negative                          2131  2131  2131  2131          2131
#
#                            capital-gain  capital-loss  education  \
# class
# decreased binding protein             9             9          9
# increased binding protein            97            97         97
# negative                           2131          2131       2131
#
#                            education-num  fnlwgt  goitre  hours-per-week  \
# class
# decreased binding protein              7       9       9               9
# increased binding protein             91      97      97              97
# negative                            1915    2131    2131            2131
#
#                            lithium  marital-status  native-country  \
# class
# decreased binding protein        9               9               9
# increased binding protein       97              97              97
# negative                      2131            2131            2131
#
#                            occupation  on thyroxine  pregnant  \
# class
# decreased binding protein           9             9         9
# increased binding protein          97            97        97
# negative                         2131          2131      2131
#
#                            query on thyroxine  race  referral source  \
# class
# decreased binding protein                   9     9                9
# increased binding protein                  97    97               97
# negative                                 2131  2131             2131
#
#                            relationship  thyroid surgery  tumor  workclass  \
# class
# decreased binding protein             9                9      9          6
# increased binding protein            97               97     97         89
# negative                           2131             2131   2131       1975
#
#                            TSH measured  query hyperthyroid  TT4 measured  \
# class
# decreased binding protein             9                   9             9
# increased binding protein            97                  97            97
# negative                           2131                2131          2131
#
#                            on antithyroid medication   FTI  sick  \
# class
# decreased binding protein                          9     9     9
# increased binding protein                         97    97    97
# negative                                        2131  2131  2131
#
#                            T4U measured  psych  query hypothyroid  cur_year  \
# class
# decreased binding protein             9      9                  9         9
# increased binding protein            97     97                 97        97
# negative                           2131   2131               2131      2130
#
#                            measured_hormones  sex_?  sex_F  sex_M
# class
# decreased binding protein                  9      9      9      9
# increased binding protein                 97     97     97     97
# negative                                2131   2131   2131   2131

# %%
#data_train[data_train['class'] == 'increased binding protein']

# %%
#sns.pairplot(data_train[data_train['class'] != 'nan'], hue='class', vars=['TT4', 'T4U', 'TSH', 'T3', 'goitre', 'tumor', 'age', 'pregnant'])

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import f1_score

# %%
def printDistribution(attribute):
    sns.distplot(data_train[data_train['class'] == 'negative'][attribute].dropna())
    sns.distplot(data_train[data_train['class'] == 'increased binding protein'][attribute].dropna())
    sns.distplot(data_train[data_train['class'] == 'decreased binding protein'][attribute].dropna())
    plt.show()

# %%
def test(name, df):
    print(" ********************** Results *************************** ")
    print("Alghoritm used= ")
    print(name)
    print(" ")

    #output = predicted[:, i].reshape(-1, 1)

    print("Accuracy Score= ")
    print(accuracy_score(df['class'], df['class_predicted']))
    print(" ")

    print("Confusion Matrix= ")
    print(confusion_matrix(df['class'], df['class_predicted']))
    print(" ")

    print("F1-Score macro= ")
    print(f1_score(df['class'], df['class_predicted'], average='macro'))
    print(" ")
    
    print("Precision/Recall/F1 Score=")
    print(classification_report(df['class'], df['class_predicted']))
    print(" ")

    print("Area Under Curve=")
    #false_positive_rate, true_positive_rate, thresholds = roc_curve(df['class'], df['class_predicted'])
    #roc_auc = auc(false_positive_rate, true_positive_rate)
    #print(roc_auc)

    print(" **********************************************************")

# %% [markdown]
# ### Pravidlo 1: Ked je T3 vacsi ako 1.5, tak ma increased binding protein

# %%
printDistribution('T3')

# %%
data_train[data_train['T3'] > 2.].groupby(['class']).count()
# Out:
#                            Unnamed: 0_x  name  address  age  sex  \
# class
# increased binding protein            82    82       82   82   82
# negative                            752   752      752  752  752
#
#                            date_of_birth  FTI measured  I131 treatment   T3  \
# class
# increased binding protein             82            82              82   82
# negative                             752           752             752  752
#
#                            T3 measured  T4U  TSH  TT4  Unnamed: 0_y  \
# class
# increased binding protein           82   82   82   82            82
# negative                           752  752  752  752           752
#
#                            capital-gain  capital-loss  education  \
# class
# increased binding protein            82            82         82
# negative                            752           752        752
#
#                            education-num  fnlwgt  goitre  hours-per-week  \
# class
# increased binding protein             77      82      82              82
# negative                             675     752     752             752
#
#                            lithium  marital-status  native-country  \
# class
# increased binding protein       82              82              82
# negative                       752             752             752
#
#                            occupation  on thyroxine  pregnant  \
# class
# increased binding protein          82            82        82
# negative                          752           752       752
#
#                            query on thyroxine  race  referral source  \
# class
# increased binding protein                  82    82               82
# negative                                  752   752              752
#
#                            relationship  thyroid surgery  tumor  workclass  \
# class
# increased binding protein            82               82     82         74
# negative                            752              752    752        709
#
#                            TSH measured  query hyperthyroid  TT4 measured  \
# class
# increased binding protein            82                  82            82
# negative                            752                 752           752
#
#                            on antithyroid medication  FTI  sick  T4U measured  \
# class
# increased binding protein                         82   82    82            82
# negative                                         752  752   752           752
#
#                            psych  query hypothyroid  cur_year  \
# class
# increased binding protein     82                 82        82
# negative                     752                752       752
#
#                            measured_hormones  sex_?  sex_F  sex_M
# class
# increased binding protein                 82     82     82     82
# negative                                 752    752    752    752

# %%
data_valid['class_predicted'] = data_valid.apply(lambda x: 'increased binding protein' if x['T3'] > 1.4 else 'negative', axis=1)
test('T3', data_valid)
# Out:
#  ********************** Results ***************************
# Alghoritm used=
# T3
#
# Accuracy Score=
# 0.3168724279835391
#
# Confusion Matrix=
# [[  0   0   5]
#  [  0  23   2]
#  [  0 657 285]]
#
# F1-Score macro=
# 0.17572023556367844
#
# Precision/Recall/F1 Score=
#                            precision    recall  f1-score   support
#
# decreased binding protein       0.00      0.00      0.00         5
# increased binding protein       0.03      0.92      0.07        25
#                  negative       0.98      0.30      0.46       942
#
#                 micro avg       0.32      0.32      0.32       972
#                 macro avg       0.34      0.41      0.18       972
#              weighted avg       0.95      0.32      0.45       972
#
#
# Area Under Curve=
#  **********************************************************
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
data_valid[data_valid['class_predicted'] != 'negative']
# Out:
#      Unnamed: 0_x                  name  \
# 0               0         Walter Acosta
# 1               1         Frances Pryor
# 3               3         Gloria Lepley
# 6               6         Jesus Reichel
# 7               7          John Nichols
# 8               8       Everett Guarino
# 10             10       Henry Alexander
# 12             12        Lyndia Yoshino
# 13             13           Flora Mcgee
# 16             16     Lillian Batchelor
# 17             17          Tawnya Barry
# 19             19           Lisa Tudela
# 21             21     Sondra Hollenbeck
# 24             24         Nettie Mclean
# 25             25       Catalina Miller
# 26             26          Stephen Lane
# 27             27            Todd Begum
# 28             28          Jason Grimes
# 29             29      Margaret Mcelroy
# 30             30         Lois Gonzalez
# 31             31         Scott Acevedo
# 33             33            Leila Gray
# 34             34          Joyce Hubley
# 35             35        Thomas Winters
# 37             37          Shirley Alba
# 38             38           Ruby Nadeau
# 39             39        Arthur Odegard
# 40             40         Donald Porter
# 41             41          John Johnson
# 42             42        Angela Wortham
# ..            ...                   ...
# 925           925            Jill Hayes
# 927           927        Albert Brennan
# 928           928       Michelle Kirgan
# 929           929         James Mallory
# 931           931         Patricia Epps
# 24                    negative      Bachelors           13.0  287547.0
# 25                    negative      Assoc-voc           11.0  162675.0
# 26                    negative   Some-college            NaN  234838.0
# 27                    negative      Bachelors           13.0  192226.0
# 28                    negative           11th            7.0  421350.0
# 29                    negative        HS-grad            9.0  331650.0
# 30                    negative        HS-grad            9.0  191878.0
# 31                    negative      Assoc-voc           11.0   13769.0
# 33   increased binding protein   Some-college           10.0  351760.0
# 34                    negative        HS-grad            9.0   68452.0
# 35                    negative   Some-college           10.0  197836.0
# 37                    negative      Assoc-voc           11.0  264874.0
# 38                    negative            9th            5.0  109996.0
# 39                    negative        HS-grad            9.0  409246.0
# 40                    negative        HS_grad            9.0  190292.0
# 41                    negative        HS-grad            9.0  697806.0
# 42                    negative   Some_college           10.0  318415.0
# ..                         ...            ...            ...       ...
# 925                   negative      Bachelors           13.0  357118.0
# 927                   negative            9th            5.0  190514.0
# 928                   negative        HS-grad            9.0  190916.0
# 929                   negative   Some-college           10.0  200565.0
# 931                   negative        HS-grad            9.0  145182.0
# 932                   negative      Assoc-voc           11.0  202652.0
# 933                   negative        5th-6th            3.0  114561.0
# 934                   negative   Some-college           10.0  159323.0
# 935                   negative      Bachelors           13.0  207965.0
# 936                   negative   Some-college           10.0   33487.0
# 937                   negative           11th            7.0  244571.0
# 939                   negative     Assoc-acdm           12.0  289448.0
# 940                   negative        HS-grad            9.0   27436.0
# 942                   negative        7th-8th            4.0  184303.0
# 946                   negative      Preschool            1.0  295591.0
# 947  increased binding protein        HS_grad            9.0   33895.0
# 948                   negative   Some-college           10.0   60639.0
# 950                   negative   Some-college           10.0  256923.0
# 951                   negative      Assoc-voc            NaN  243190.0
# 953                   negative   Some-college           10.0   73493.0
# 955                   negative        HS-grad            9.0  139522.0
# 956                   negative        HS-grad            9.0  166289.0
# 957  increased binding protein        Masters           14.0  187031.0
# 958                   negative        Masters           14.0  133136.0
# 961                   negative      Bachelors           13.0  122109.0
# 963                   negative      Bachelors           13.0  245525.0
# 964                   negative           10th            6.0   91141.0
# 965                   negative        HS-grad            9.0  172538.0
# 969                   negative        HS-grad            9.0  181578.0
# 970                   negative      Bachelors           13.0  120131.0
#
#      goitre  hours-per-week  lithium          marital-status  native-country  \
# 0         0            40.0      0.0      Married-civ-spouse            Cuba
# 1         0            54.0      0.0                 Widowed   United-States
# 3         0            40.0      0.0           Never-married   United-States
# 6         0            40.0      0.0               Separated   United-States
# 7         0            40.0      0.0           Never-married   United-States
# 8         0            40.0      0.0      Married-civ-spouse   United-States
# 10        0            45.0      0.0           Never-married   United-States
# 12        0            50.0      0.0      Married-civ-spouse   United-States
# 13        0            40.0      0.0   Married-spouse-absent   United-States
# 16        0            40.0      0.0               Separated   United-States
# 17        0            20.0      0.0                Divorced   United-States
# 19        0            50.0      0.0                Divorced   United-States
# 21        0            30.0      0.0                Divorced   United-States
# 24        0            40.0      0.0      Married-civ-spouse   United-States
# 25        0            35.0      0.0           Never-married            Cuba
# 26        0            30.0      0.0           Never-married   United-States
# 27        0            55.0      0.0      Married-civ-spouse   United-States
# 28        0            20.0      0.0           Never-married   United-States
# 29        0            40.0      0.0      Married-civ-spouse   United-States
# 30        0            35.0      0.0           Never-married   United-States
# 31        0            40.0      0.0                Divorced   United-States
# 33        0            35.0      0.0                Divorced   United-States
# 34        1            40.0      0.0               Separated   United-States
# 35        0            40.0      0.0      Married-civ-spouse   United-States
# 37        0            40.0      0.0           Never-married               ?
# 38        0            40.0      0.0      Married-civ-spouse            Hong
# 39        0            40.0      0.0      Married-civ-spouse   United-States
# 40        0            40.0      0.0                Divorced   United-States
# 41        0            60.0      0.0      Married-civ-spouse   United-States
# 42        0            40.0      0.0                Divorced   United-States
# ..      ...             ...      ...                     ...             ...
# 925       0            40.0      0.0                 Widowed   United-States
# 927       0            40.0      0.0      Married-civ-spouse   United-States
# 928       0            20.0      0.0           Never-married   United-States
# 929       0            18.0      0.0      Married-civ-spouse   United-States
# 931       0            20.0      0.0           Never-married   United-States
# 932       0            30.0      0.0      Married-civ-spouse   United-States
# 933       0            25.0      0.0                 Widowed     Philippines
# 934       0            65.0      0.0                Divorced          Canada
# 935       0            60.0      0.0           Never-married   United-States
# 936       0            38.0      0.0                Divorced   United-States
# 937       0            10.0      0.0           Never-married   United-States
# 939       0            30.0      0.0           Never-married     Philippines
# 940       0            35.0      0.0                Divorced   United-States
# 942       0            40.0      0.0           Never-married       Guatemala
# 946       0            40.0      0.0           Never-married          Mexico
# 947       0            40.0      0.0                Divorced   United-States
# 948       0            40.0      0.0           Never-married   United-States
# 950       0            40.0      0.0      Married-civ-spouse   United-States
# 951       0            40.0      0.0                Divorced   United-States
# 953       0            60.0      0.0               Separated   United-States
# 955       0            40.0      0.0      Married-civ-spouse           Italy
# 956       0            40.0      0.0           Never-married   United-States
# 957       0            38.0      0.0           Never-married   United-States
# 958       0            35.0      0.0           Never-married   United-States
# 961       0            50.0      0.0                Divorced   United-States
# 963       0            38.0      0.0      Married-civ-spouse   United-States
# 964       0             8.0      0.0           Never-married   United-States
# 965       0            55.0      0.0      Married-civ-spouse   United-States
# 969       0            40.0      0.0      Married-civ-spouse               ?
# 970       0            40.0      0.0      Married-civ-spouse   United-States
#
#              occupation  on thyroxine  pregnant  query on thyroxine  \
# 0          Adm-clerical           0.0         0                 0.0
# 1                     ?           1.0         1                 0.0
# 3     Machine-op-inspct           0.0         0                 0.0
# 6          Tech-support           0.0         0                 0.0
# 7          Adm-clerical           0.0         0                 0.0
# 8        Prof-specialty           0.0         0                 0.0
# 10        Other-service           0.0         0                 0.0
# 12                    ?           0.0         0                 0.0
# 13                Sales           1.0         0                 0.0
# 16         Tech-support           0.0         0                 0.0
# 17         Adm-clerical           1.0         0                 0.0
# 19       Prof-specialty           0.0         0                 0.0
# 21         Adm-clerical           1.0         0                 0.0
# 24       Prof-specialty           0.0         0                 0.0
# 25         Adm-clerical           1.0         0                 0.0
# 26                    ?           0.0         0                 0.0
# 27      Exec-managerial           0.0         0                 0.0
# 28    Handlers-cleaners           0.0         0                 0.0
# 29         Adm-clerical           0.0         0                 0.0
# 30        Other-service           1.0         0                 0.0
# 31       Prof-specialty           0.0         0                 0.0
# 33         Adm-clerical           0.0         0                 0.0
# 34    Machine-op-inspct           0.0         0                 0.0
# 35    Machine-op-inspct           1.0         0                 0.0
# 37                    ?           0.0         0                 0.0
# 38        Other-service           1.0         0                 0.0
# 39      Farming-fishing           0.0         0                 0.0
# 40    Machine-op-inspct           0.0         0                 0.0
# 41     Transport-moving           0.0         0                 0.0
# 42    Machine-op-inspct           1.0         0                 0.0
# ..                  ...           ...       ...                 ...
# 925     Exec-managerial           0.0         0                 0.0
# 927                   ?           0.0         0                 0.0
# 928       Other-service           0.0         0                 0.0
# 929               Sales           0.0         0                 0.0
# 931     Protective-serv           0.0         0                 0.0
# 932               Sales           0.0         0                 0.0
# 933       Other-service           1.0         0                 0.0
# 934               Sales           0.0         0                 0.0
# 935       Other-service           0.0         0                 0.0
# 936        Adm-clerical           0.0         0                 0.0
# 937        Adm-clerical           0.0         0                 0.0
# 939        Adm-clerical           0.0         0                 0.0
# 940       Other-service           0.0         0                 0.0
# 942     Priv-house-serv           0.0         0                 0.0
# 946     Farming-fishing           0.0         0                 0.0
# 947        Tech-support           0.0         0                 0.0
# 948       Other-service           0.0         0                 0.0
# 950     Exec-managerial           0.0         0                 0.0
# 951        Tech-support           0.0         0                 0.0
# 953     Exec-managerial           1.0         0                 0.0
# 955       Other-service           0.0         0                 0.0
# 956        Adm-clerical           0.0         0                 0.0
# 957               Sales           0.0         1                 1.0
# 958      Prof-specialty           0.0         0                 0.0
# 961     Exec-managerial           0.0         0                 0.0
# 963   Handlers-cleaners           0.0         0                 0.0
# 964               Sales           0.0         0                 0.0
# 965               Sales           0.0         0                 0.0
# 969       Other-service           0.0         0                 0.0
# 970     Exec-managerial           0.0         0                 0.0
#
#                     race referral source     relationship  thyroid surgery  \
# 0                  White           other          Husband                0
# 1                  Black           other        Unmarried                0
# 3                  White            SVHC        Unmarried                0
# 6                  Black           other        Unmarried                0
# 7                  White           other    Not-in-family                0
# 8                  White           other          Husband                0
# 10                 White            SVHC    Not-in-family                0
# 12                 White           Other             Wife                0
# 13                 White           other    Not-in-family                0
# 16                 Black            SVHC   Other-relative                0
# 17                 White           other   Other-relative                0
# 19                 White           other        Unmarried                0
# 21                 White           other        Unmarried                0
# 24                 White           other             Wife                0
# 25                 White           other        Own-child                0
# 26                 White             SVI        Own-child                0
# 27                 White             SVI          Husband                0
# 28                 White           Other        Own-child                0
# 29                 White           other             Wife                0
# 30                 Black           other    Not-in-family                0
# 31                 White            SVHC        Unmarried                0
# 33                 White             SVI    Not-in-family                0
# 34                 Black           other        Unmarried                0
# 35                 White           other          Husband                0
# 37                 White             SVI   Other-relative                0
# 38    Asian-Pac-Islander           Other             Wife                0
# 39                 White             SVI          Husband                0
# 40                 White           other        Unmarried                0
# 41                 White             SVI          Husband                0
# 42                 Black           other        Unmarried                1
# ..                   ...             ...              ...              ...
# 964                0.0      2018                  3      1      0      0
# 965                0.0      2018                  5      0      0      1
# 969                0.0      2018                  5      0      1      0
# 970                0.0      2018                  5      0      0      1
#
#                class_predicted
# 0    increased binding protein
# 1    increased binding protein
# 3    increased binding protein
# 6    increased binding protein
# 7    increased binding protein
# 8    increased binding protein
# 10   increased binding protein
# 12   increased binding protein
# 13   increased binding protein
# 16   increased binding protein
# 17   increased binding protein
# 19   increased binding protein
# 21   increased binding protein
# 24   increased binding protein
# 25   increased binding protein
# 26   increased binding protein
# 27   increased binding protein
# 28   increased binding protein
# 29   increased binding protein
# 30   increased binding protein
# 31   increased binding protein
# 33   increased binding protein
# 34   increased binding protein
# 35   increased binding protein
# 37   increased binding protein
# 38   increased binding protein
# 39   increased binding protein
# 40   increased binding protein
# 41   increased binding protein
# 42   increased binding protein
# ..                         ...
# 925  increased binding protein
# 927  increased binding protein
# 928  increased binding protein
# 929  increased binding protein
# 931  increased binding protein
# 932  increased binding protein
# 933  increased binding protein
# 934  increased binding protein
# 935  increased binding protein
# 936  increased binding protein
# 937  increased binding protein
# 939  increased binding protein
# 940  increased binding protein
# 942  increased binding protein
# 946  increased binding protein
# 947  increased binding protein
# 948  increased binding protein
# 950  increased binding protein
# 951  increased binding protein
# 953  increased binding protein
# 955  increased binding protein
# 956  increased binding protein
# 957  increased binding protein
# 958  increased binding protein
# 961  increased binding protein
# 963  increased binding protein
# 964  increased binding protein
# 965  increased binding protein
# 969  increased binding protein
# 970  increased binding protein
#
# [680 rows x 50 columns]

# %% [markdown]
# ### Pravidlo 2: Ked je T4U vacsi ako 0.25, tak ma increased binding protein

# %%
printDistribution('T4U')

# %%
data_train[data_train['T4U'] > 1.1].groupby(['class']).count()
# Out:
#                            Unnamed: 0_x  name  address  age  sex  \
# class
# increased binding protein            86    86       86   86   86
# negative                            330   330      330  330  330
#
#                            date_of_birth  FTI measured  I131 treatment   T3  \
# class
# increased binding protein             86            86              86   86
# negative                             330           330             330  330
#
#                            T3 measured  T4U  TSH  TT4  Unnamed: 0_y  \
# class
# increased binding protein           86   86   86   86            86
# negative                           330  330  330  330           330
#
#                            capital-gain  capital-loss  education  \
# class
# increased binding protein            86            86         86
# negative                            330           330        330
#
#                            education-num  fnlwgt  goitre  hours-per-week  \
# class
# increased binding protein             80      86      86              86
# negative                             299     330     330             330
#
#                            lithium  marital-status  native-country  \
# class
# increased binding protein       86              86              86
# negative                       330             330             330
#
#                            occupation  on thyroxine  pregnant  \
# class
# increased binding protein          86            86        86
# negative                          330           330       330
#
#                            query on thyroxine  race  referral source  \
# class
# increased binding protein                  86    86               86
# negative                                  330   330              330
#
#                            relationship  thyroid surgery  tumor  workclass  \
# class
# increased binding protein            86               86     86         78
# negative                            330              330    330        309
#
#                            TSH measured  query hyperthyroid  TT4 measured  \
# class
# increased binding protein            86                  86            86
# negative                            330                 330           330
#
#                            on antithyroid medication  FTI  sick  T4U measured  \
# class
# increased binding protein                         86   86    86            86
# negative                                         330  330   330           330
#
#                            psych  query hypothyroid  cur_year  \
# class
# increased binding protein     86                 86        86
# negative                     330                330       330
#
#                            measured_hormones  sex_?  sex_F  sex_M
# class
# increased binding protein                 86     86     86     86
# negative                                 330    330    330    330

# %%
data_valid['class_predicted'] = data_valid['T4U'].apply(lambda x: 'increased binding protein' if x > 1.1 else 'negative')
test('T4U', data_valid)
# Out:
#  ********************** Results ***************************
# Alghoritm used=
# T4U
#
# Accuracy Score=
# 0.8281893004115226
#
# Confusion Matrix=
# [[  0   0   5]
#  [  0  23   2]
#  [  0 160 782]]
#
# F1-Score macro=
# 0.374892606911671
#
# Precision/Recall/F1 Score=
#                            precision    recall  f1-score   support
#
# decreased binding protein       0.00      0.00      0.00         5
# increased binding protein       0.13      0.92      0.22        25
#                  negative       0.99      0.83      0.90       942
#
#                 micro avg       0.83      0.83      0.83       972
#                 macro avg       0.37      0.58      0.37       972
#              weighted avg       0.96      0.83      0.88       972
#
#
# Area Under Curve=
#  **********************************************************
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Pravidlo 3: Ked je zena po 25 tehotna, tak ma increased binding protein

# %%
printDistribution('pregnant')
# Out:
# /Users/edvin/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /Users/edvin/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
data_train[(data_train['pregnant'] > 0.85) & (data_train['age'] > 25)].groupby(['class']).count()
# Out:
#                            Unnamed: 0_x  name  address  age  sex  \
# class
# increased binding protein            21    21       21   21   21
# negative                              9     9        9    9    9
#
#                            date_of_birth  FTI measured  I131 treatment  T3  \
# class
# increased binding protein             21            21              21  21
# negative                               9             9               9   9
#
#                            T3 measured  T4U  TSH  TT4  Unnamed: 0_y  \
# class
# increased binding protein           21   21   21   21            21
# negative                             9    9    9    9             9
#
#                            capital-gain  capital-loss  education  \
# class
# increased binding protein            21            21         21
# negative                              9             9          9
#
#                            education-num  fnlwgt  goitre  hours-per-week  \
# class
# increased binding protein             20      21      21              21
# negative                               8       9       9               9
#
#                            lithium  marital-status  native-country  \
# class
# increased binding protein       21              21              21
# negative                         9               9               9
#
#                            occupation  on thyroxine  pregnant  \
# class
# increased binding protein          21            21        21
# negative                            9             9         9
#
#                            query on thyroxine  race  referral source  \
# class
# increased binding protein                  21    21               21
# negative                                    9     9                9
#
#                            relationship  thyroid surgery  tumor  workclass  \
# class
# increased binding protein            21               21     21         18
# negative                              9                9      9          8
#
#                            TSH measured  query hyperthyroid  TT4 measured  \
# class
# increased binding protein            21                  21            21
# negative                              9                   9             9
#
#                            on antithyroid medication  FTI  sick  T4U measured  \
# class
# increased binding protein                         21   21    21            21
# negative                                           9    9     9             9
#
#                            psych  query hypothyroid  cur_year  \
# class
# increased binding protein     21                 21        21
# negative                       9                  9         9
#
#                            measured_hormones  sex_?  sex_F  sex_M
# class
# increased binding protein                 21     21     21     21
# negative                                   9      9      9      9

# %%
def ruleAgePregnant(row):
    if row['pregnant'] > 0.85 and row['age'] > 25:
        return 'increased binding protein'
    return 'negative'
data_valid['class_predicted'] = data_valid.apply(lambda x: ruleAgePregnant(x), axis=1)
test('pregnant', data_valid)
# Out:
#  ********************** Results ***************************
# Alghoritm used=
# pregnant
#
# Accuracy Score=
# 0.9691358024691358
#
# Confusion Matrix=
# [[  0   0   5]
#  [  0   5  20]
#  [  0   5 937]]
#
# F1-Score macro=
# 0.4233193277310925
#
# Precision/Recall/F1 Score=
#                            precision    recall  f1-score   support
#
# decreased binding protein       0.00      0.00      0.00         5
# increased binding protein       0.50      0.20      0.29        25
#                  negative       0.97      0.99      0.98       942
#
#                 micro avg       0.97      0.97      0.97       972
#                 macro avg       0.49      0.40      0.42       972
#              weighted avg       0.96      0.97      0.96       972
#
#
# Area Under Curve=
#  **********************************************************
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1289: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
printDistribution('TSH')

# %% [markdown]
# ----

# %% [markdown]
# # Predikcia

# %% [markdown]
# #### Zadefinovanie funkcie pre vyhodnocovania vysledkov

# %%
def score(name, predicted, valid):
    print(" ********************** Results *************************** ")
    print("Alghoritm used= ")
    print(name)
    print(" ")

    print("Accuracy Score= ")
    print(accuracy_score(valid, predicted))
    print(" ")

    print("Confusion Matrix= ")
    print(confusion_matrix(valid, predicted))
    print(" ")

    print("Precision/Recall/F1 Score=")
    print(classification_report(valid, predicted))
    print(" ")

    print(" **********************************************************")

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2237 entries, 0 to 2236
# Data columns (total 49 columns):
# Unnamed: 0_x                 2237 non-null int64
# name                         2237 non-null object
# address                      2237 non-null object
# age                          2237 non-null float64
# sex                          2237 non-null object
# date_of_birth                2236 non-null object
# FTI measured                 2237 non-null int64
# I131 treatment               2237 non-null int64
# T3                           2237 non-null float64
# T3 measured                  2237 non-null int64
# T4U                          2237 non-null float64
# TSH                          2237 non-null float64
# TT4                          2237 non-null float64
# Unnamed: 0_y                 2237 non-null float64
# capital-gain                 2237 non-null float64
# capital-loss                 2237 non-null float64
# class                        2237 non-null object
# education                    2237 non-null object
# education-num                2013 non-null float64
# fnlwgt                       2237 non-null float64
# goitre                       2237 non-null int64
# hours-per-week               2237 non-null float64
# lithium                      2237 non-null float64
# marital-status               2237 non-null object
# native-country               2237 non-null object
# occupation                   2237 non-null object
# on thyroxine                 2237 non-null float64
# pregnant                     2237 non-null int64
# query on thyroxine           2237 non-null float64
# race                         2237 non-null object
# referral source              2237 non-null object
# relationship                 2237 non-null object
# thyroid surgery              2237 non-null int64
# tumor                        2237 non-null float64
# workclass                    2070 non-null object
# TSH measured                 2237 non-null int64
# query hyperthyroid           2237 non-null int64
# TT4 measured                 2237 non-null int64
# on antithyroid medication    2237 non-null int64
# FTI                          2237 non-null float64
# sick                         2237 non-null int64
# T4U measured                 2237 non-null int64
# psych                        2237 non-null int64
# query hypothyroid            2237 non-null int64
# cur_year                     2236 non-null float64
# measured_hormones            2237 non-null int64
# sex_?                        2237 non-null uint8
# sex_F                        2237 non-null uint8
# sex_M                        2237 non-null uint8
# dtypes: float64(17), int64(16), object(13), uint8(3)
# memory usage: 908.0+ KB

# %%
printDistribution('lithium')
# Out:
# /Users/edvin/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/edvin/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /Users/edvin/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
reduce_ppl = Pipeline([
    ('column_selector', d16.ColumnSelector(['T3', 'T4U', 'TSH', 'TT4', 'FTI', 'class', 'sex_F', 'sex_M', 'measured_hormones', 'lithium'])),
])

# %%
data_train_selected = reduce_ppl.transform(data_train)
data_valid_selected = reduce_ppl.transform(data_valid)
data_test_selected = reduce_ppl.transform(data_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

# %%
# Rozdelenie trenovacich dat pre natrenovanie klasifikatoru
X_train = data_train_selected.drop(['class'], axis=1)
Y_train = le.fit_transform(data_train_selected[['class']])

# Rozdelenie validacnych dat
X_valid = data_valid_selected.drop(['class'], axis=1)
Y_valid = le.fit_transform(data_valid_selected[['class']])

# Rozdelenie testovacich dat na trenovacie a testovacie
X_test = data_test_selected.drop(['class'], axis=1)
# Out:
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Natrenovanie nahodneho lesu pre predikcie

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced', np.unique(Y_train), Y_train)
class_weights
# Out:
# array([82.85185185,  7.68728522,  0.34991397])

# %%
clf = RandomForestClassifier(class_weight='balanced', max_depth=15, n_estimators=200) #{2:0.35, 1:7.68, 0:82.51}'balanced'

clf.fit(X_train, Y_train)
predictions = clf.predict(X_valid)

# %%
score("Random Forest", Y_valid, predictions)
# Out:
#  ********************** Results ***************************
# Alghoritm used=
# Random Forest
#
# Accuracy Score=
# 0.9742798353909465
#
# Confusion Matrix=
# [[  0   0   0]
#  [  0  15  10]
#  [  5  10 932]]
#
# Precision/Recall/F1 Score=
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.60      0.60      0.60        25
#            2       0.99      0.98      0.99       947
#
#    micro avg       0.97      0.97      0.97       972
#    macro avg       0.53      0.53      0.53       972
# weighted avg       0.98      0.97      0.98       972
#
#
#  **********************************************************
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1291: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1291: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1291: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# ### Natrenovanie logistickej regresie pre predikciu

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(solver='liblinear')
lr.fit(X_train, Y_train)

predictions = lr.predict(X_valid)
# Out:
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:464: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
score("Logistic Regression", Y_valid, predictions)
# Out:
#  ********************** Results ***************************
# Alghoritm used=
# Logistic Regression
#
# Accuracy Score=
# 0.9732510288065843
#
# Confusion Matrix=
# [[  0   0   0]
#  [  0  13   9]
#  [  5  12 933]]
#
# Precision/Recall/F1 Score=
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.52      0.59      0.55        22
#            2       0.99      0.98      0.99       950
#
#    micro avg       0.97      0.97      0.97       972
#    macro avg       0.50      0.52      0.51       972
# weighted avg       0.98      0.97      0.98       972
#
#
#  **********************************************************
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1291: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1291: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /Users/edvin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1291: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# - Age
# - One hot encoding

# %% [markdown]
# ### Natrenovanie rozhodovacieho stromu pre predikcie

# %%
clf = DecisionTreeClassifier(class_weight='balanced', max_depth=9)
clf.fit(X_train, Y_train)
predictions = clf.predict(X_valid)

# %%
score("CART", Y_valid, predictions)
# Out:
#  ********************** Results ***************************
# Alghoritm used=
# CART
#
# Accuracy Score=
# 0.9629629629629629
#
# Confusion Matrix=
# [[  4   0   2]
#  [  0  19  27]
#  [  1   6 913]]
#
# Precision/Recall/F1 Score=
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.76      0.41      0.54        46
#            2       0.97      0.99      0.98       920
#
#    micro avg       0.96      0.96      0.96       972
#    macro avg       0.84      0.69      0.75       972
# weighted avg       0.96      0.96      0.96       972
#
#
#  **********************************************************

# %%
test_predict = clf.predict(X_test)

# %%
predictions = pd.DataFrame(le.inverse_transform(test_predict))
predictions = predictions.rename(index=str, columns={0: "Predicted"})
predictions.to_csv('out.csv', index_label='Id')

# %%
from sklearn.tree import export_graphviz
from graphviz import Source
from IPython.display import SVG

graph = Source(export_graphviz(clf, 
                               out_file=None,
                               feature_names=X_train.columns,
                               class_names=le.inverse_transform(Y_train),
                               filled = True))

display(SVG(graph.pipe(format='svg')))

from IPython.display import HTML # toto je tu len pre to aby sa mi obrazok zmestil na obrazovku
style = "<style>svg{width:40% !important;height:40% !important;}</style>"
HTML(style)
# Out:
# <style>svg{width:40% !important;height:40% !important;}</style>

# %% [markdown]
# Kedze stromcek mal zatial najlepsiu predikciu, skusime sa ho optimalizovat

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(clf, X_train, Y_train, cv=5, scoring = 'f1_micro')
scores.mean()
# Out:
# 0.9615510581742555

# %% [markdown]
# Skusime pouzit grid search

# %%
from sklearn.model_selection import GridSearchCV

cv_params = {'max_depth': [8, 9, 10, 11, 12, 13, 14, 15], 'criterion': ['gini', 'entropy'], 'min_samples_leaf': [1, 2, 3] }
ind_params = {'random_state': 0}
optimization = GridSearchCV(clf(**ind_params), cv_params, scoring = 'f1_macro', cv = 5, n_jobs = -1, verbose=True)

# %%
from sklearn.model_selection import ParameterGrid
print(len(ParameterGrid(cv_params)))
list(ParameterGrid(cv_params))
# Out:
# 48
# [{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 3},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2},
#  {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 3},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2},
#  {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 3}]

# %%
optimization.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:    2.8s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best'),
#        iid='warn', n_jobs=-1,
#        param_grid={'max_depth': [8, 9, 10, 11, 12, 13, 14, 15], 'criterion': ['gini', 'entropy'], 'min_samples_leaf': [1, 2, 3]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring='f1_macro', verbose=True)

# %%
optimization.cv_results_
# Out:
# {'mean_fit_time': array([0.00656161, 0.00551939, 0.00398617, 0.00389991, 0.00393581,
#         0.00377407, 0.00385633, 0.00378442, 0.00376701, 0.00480433,
#         0.00542579, 0.00506644, 0.00462518, 0.00397997, 0.00367241,
#         0.00364718, 0.00461221, 0.00461812, 0.00473843, 0.00508103,
#         0.00465074, 0.00550189, 0.00482683, 0.00505433, 0.00498915,
#         0.00533586, 0.0050724 , 0.00561118, 0.00538549, 0.00526214,
#         0.00522027, 0.00593758, 0.00525064, 0.00571227, 0.00522766,
#         0.00531139, 0.00525599, 0.00531478, 0.00491724, 0.00490813,
#         0.00625935, 0.00458827, 0.00529184, 0.00390387, 0.00519671,
#         0.0040884 , 0.00464892, 0.00396099]),
#  'std_fit_time': array([1.99322301e-04, 1.18625830e-03, 3.07287916e-04, 1.88027878e-04,
#         2.27124751e-04, 2.39440521e-04, 2.54565831e-04, 2.23267613e-04,
#         8.71699539e-05, 9.13455121e-04, 4.72400424e-04, 3.86689811e-04,
#         4.36576973e-04, 4.39590339e-04, 1.61076298e-04, 1.49024436e-04,
#         8.83559735e-04, 7.61485314e-04, 6.90219136e-04, 1.13837579e-04,
#         7.88749856e-04, 6.62889760e-04, 3.55376705e-04, 2.64368712e-04,
#         4.56732567e-04, 6.62865488e-04, 4.27711725e-04, 5.83027079e-04,
#         7.14600415e-04, 3.24765209e-04, 3.85853894e-04, 1.60729285e-03,
#         4.82477716e-04, 7.33308625e-04, 3.71012423e-04, 4.44307376e-04,
#         3.72323461e-04, 3.62508951e-04, 2.47241175e-04, 8.13798148e-04,
#         5.30127399e-04, 1.20779212e-03, 3.88952934e-04, 5.51540909e-04,
#         4.98043951e-04, 5.86861702e-04, 1.26110023e-03, 6.26712332e-04]),
#  'mean_score_time': array([0.00292416, 0.00182462, 0.00146298, 0.00137081, 0.00132461,
#         0.00152159, 0.0014081 , 0.00139842, 0.00131364, 0.00213242,
#         0.00186524, 0.00179925, 0.00188761, 0.00132704, 0.00139146,
#         0.00136156, 0.00183082, 0.00177579, 0.00188274, 0.00194454,
#         0.00175886, 0.00194783, 0.001931  , 0.00221581, 0.0018508 ,
#         0.00196109, 0.00215554, 0.00216737, 0.00227938, 0.00320272,
#         0.00203524, 0.00216565, 0.00524154, 0.00210094, 0.00222516,
#         0.00207   , 0.00189857, 0.00229535, 0.00186572, 0.00194602,
#         0.00198641, 0.00203276, 0.00205388, 0.00134993, 0.00210652,
#         0.00155869, 0.00169258, 0.00145469]),
#  'std_score_time': array([1.41893882e-03, 4.77307279e-04, 2.79084377e-04, 9.42161448e-05,
#         8.61291729e-05, 2.84082515e-04, 1.15385824e-04, 1.29818564e-04,
#         2.33559688e-05, 1.47414421e-04, 1.32766365e-04, 1.52142859e-04,
#         8.59972080e-05, 7.30132521e-05, 3.67905977e-04, 2.63539464e-04,
#         2.55846310e-04, 2.83244900e-04, 3.15662504e-04, 3.76619861e-05,
#         3.23229033e-04, 4.47021548e-05, 3.20311058e-04, 3.21361338e-04,
#         2.20407494e-04, 2.68780997e-04, 3.14890241e-04, 3.75293340e-04,
#         2.27885991e-04, 2.16232321e-03, 7.81467003e-05, 3.24238349e-04,
#         4.73634576e-03, 1.75697379e-04, 5.23062477e-04, 1.22871545e-04,
#         3.49052858e-04, 3.55015963e-04, 2.64177365e-04, 3.87191579e-04,
#         1.20240765e-04, 1.05141686e-03, 7.93025640e-05, 3.30852836e-04,
#         1.38026246e-04, 2.40122505e-04, 4.69677131e-04, 3.63346398e-04]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[8, 8, 8, 9, 9, 9, 10, 10, 10, 11, 11, 11, 12, 12, 12,
#                     13, 13, 13, 14, 14, 14, 15, 15, 15, 8, 8, 8, 9, 9, 9,
#                     10, 10, 10, 11, 11, 11, 12, 12, 12, 13, 13, 13, 14, 14,
#                     14, 15, 15, 15],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3,
#                     1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3,
#                     1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 3},
#   {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1},
#   {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 2},
#   {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3},
#   {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf':
#         0.59766418, 0.67654512, 0.6345614 , 0.59282785, 0.67654512,
#         0.6345614 , 0.58566652, 0.67654512, 0.6345614 , 0.58100128,
#         0.67654512, 0.6345614 , 0.60271564, 0.67654512, 0.6345614 ,
#         0.60271564, 0.67654512, 0.6345614 ]),
#  'split4_test_score': array([0.54408507, 0.54968011, 0.53118908, 0.53220176, 0.54968011,
#         0.53118908, 0.53220176, 0.54968011, 0.53118908, 0.53220176,
#         0.54968011, 0.53118908, 0.53220176, 0.54968011, 0.53118908,
#         0.53220176, 0.54968011, 0.53118908, 0.53220176, 0.54968011,
#         0.53118908, 0.53220176, 0.54968011, 0.53118908, 0.55548541,
#         0.5559262 , 0.55548541, 0.54412456, 0.57425253, 0.56795474,
#         0.53799798, 0.57425253, 0.56795474, 0.53799798, 0.57425253,
#         0.56795474, 0.53799798, 0.57425253, 0.56795474, 0.53799798,
#         0.57425253, 0.56795474, 0.53799798, 0.57425253, 0.56795474,
#         0.53799798, 0.57425253, 0.56795474]),
#  'mean_test_score': array([0.61965078, 0.61813006, 0.62414661, 0.63184184, 0.6203006 ,
#         0.62575257, 0.62388354, 0.61893424, 0.62783019, 0.61984675,
#         0.61721627, 0.62783019, 0.61984675, 0.61721627, 0.62783019,
#         0.61767172, 0.61721627, 0.62783019, 0.61767172, 0.61721627,
#         0.62783019, 0.61767172, 0.61721627, 0.62783019, 0.58659433,
#         0.59215747, 0.6021104 , 0.57618909, 0.61411578, 0.60359886,
#         0.58109516, 0.61414133, 0.60359886, 0.57881145, 0.61414133,
#         0.60359886, 0.5749246 , 0.61414133, 0.60359886, 0.57399238,
#         0.61414133, 0.60359886, 0.57833137, 0.61414133, 0.60359886,
#         0.57833137, 0.61414133, 0.60359886]),
#  'std_test_score': array([0.05606893, 0.04403633, 0.06586476, 0.07415039, 0.04651094,
#         0.06927977, 0.07505425, 0.04763548, 0.06756579, 0.06601252,
#         0.04467164, 0.06756579, 0.06601252, 0.04467164, 0.06756579,
#         0.06792896, 0.04467164, 0.06756579, 0.06792896, 0.04467164,
#         0.06756579, 0.06792896, 0.04467164, 0.06756579, 0.04193144,
#         0.055914  , 0.05300327, 0.03962944, 0.06066762, 0.04548409,
#         0.03851848, 0.06069388, 0.04548409, 0.0389089 , 0.06069388,
#         0.04548409, 0.04026101, 0.06069388, 0.04548409, 0.04005498,
#         0.06069388, 0.04548409, 0.04172069, 0.06069388, 0.04548409,
#         0.04172069, 0.06069388, 0.04548409]),
#  'rank_test_score': array([14, 16,  9,  1, 11,  8, 10, 15,  2, 12, 20,  2, 12, 20,  2, 17, 20,
#          2, 17, 20,  2, 17, 20,  2, 41, 40, 39, 46, 31, 32, 42, 25, 32, 43,
#         25, 32, 47, 25, 32, 48, 25, 32, 44, 25, 32, 44, 25, 32],
#        dtype=int32)}

# %%
optimization.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=9,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
optimization.best_score_
# Out:
# 0.6318418391257924

# %% [markdown]
# Skusime teda zobrat max_depth=9 kedze tak nam hovori optimizacia. (Pred bol max_depth setnuty na 10).
