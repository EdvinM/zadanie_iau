# %%
import pandas as pd

# %%
data_personal = pd.read_csv("personal_train.csv")
data_other = pd.read_csv("other_train.csv")

# %%
data_personal.head()
# Out:
#    Unnamed: 0              name  \
# 0           0       Terry Terry
# 1           1      Stephen Lalk
# 2           2     Abraham Bruce
# 3           3   Edith Boudreaux
# 4           4  Janet Washington
#
#                                              address   age sex  \
# 0   11818 Lori Crossing Apt. 802\nPughstad, DC 78165  24.0   M
# 1                   PSC 4657, Box 5446\nAPO AP 58412  44.0   M
# 2                   Unit 9759 Box 9470\nDPO AP 45549  56.0   M
# 3  137 Lewis Flat Suite 762\nWest Elizabeth, AL 3...  71.0   F
# 4   995 Frank Stravenue\nSouth Matthewport, TX 81402  63.0   F
#
#          date_of_birth
# 0             94-05-02
# 1  1974-04-29 00 00 00
# 2           1962-06-09
# 3  1946-12-16 00 00 00
# 4           1955-10-15

# %%
data_other.head()
# Out:
#    Unnamed: 0             name  \
# 0           0  Latonya Wilhelm
# 1           1  Stacy Martinson
# 2           2      Linda Derby
# 3           3  Albert Cipriano
# 4           4       David Cook
#
#                                              address FTI measured  \
# 0  397 Joshua Forge Suite 012\nEast Ericburgh, WV...            f
# 1   59472 Brian Views Apt. 885\nKeithhaven, KS 03608            t
# 2                   Unit 5333 Box 7103\nDPO AA 03763            t
# 3    38302 Bradshaw Rue\nNorth Hannahshire, NC 34515            t
# 4  7984 Jason Motorway Suite 440\nNelsonville, OK...            t
#
#        education lithium    TT4   T4U  capital-loss  capital-gain   ...     \
# 0           11th       f    NaN   NaN           0.0           0.0   ...
# 1           11th       f  124.0  1.04           0.0           0.0   ...
# 2        HS-grad       f   60.0  1.04           0.0           0.0   ...
# 3      Bachelors       f  101.0  0.81           0.0           0.0   ...
# ...

# %%
data_personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 6 columns):
# Unnamed: 0       2237 non-null int64
# name             2237 non-null object
# address          2237 non-null object
# age              2236 non-null float64
# sex              2237 non-null object
# date_of_birth    2236 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 104.9+ KB

# %%
data_personal.describe()
# Out:
#         Unnamed: 0          age
# count  2237.000000  2236.000000
# mean   1118.000000    51.822004
# std     645.910598    20.884439
# min       0.000000     1.000000
# 25%     559.000000    36.000000
# 50%    1118.000000    54.000000
# 75%    1677.000000    67.000000
# max    2236.000000   455.000000

# %%
data_other.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 35 columns):
# Unnamed: 0            2287 non-null int64
# name                  2287 non-null object
# address               2287 non-null object
# FTI measured          2280 non-null object
# education             2279 non-null object
# lithium               2278 non-null object
# TT4                   2126 non-null float64
# T4U                   2039 non-null float64
# capital-loss          2281 non-null float64
# capital-gain          2279 non-null float64
# on thyroxine          2272 non-null object
# tumor                 2276 non-null object
# TSH                   2038 non-null float64
# T3                    1804 non-null float64
# fnlwgt                2277 non-null float64
# hours-per-week        2276 non-null float64
# relationship          2278 non-null object
# thyroid surgery       2283 non-null object
# workclass             2109 non-null object
# ...

# %%
data_other.describe()
# Out:
#         Unnamed: 0          TT4          T4U   capital-loss  capital-gain  \
# count  2287.000000  2126.000000  2039.000000    2281.000000   2279.000000
# mean   1143.000000   109.462088     0.996436     194.064007    817.727512
# std     660.344355    35.879295     0.191213    9116.985776   5971.192914
# min       0.000000     2.000000     0.310000 -200100.000000      0.000000
# 25%     571.500000    88.000000     0.880000       0.000000      0.000000
# 50%    1143.000000   104.000000     0.980000       0.000000      0.000000
# 75%    1714.500000   126.000000     1.080000       0.000000      0.000000
# max    2286.000000   430.000000     2.120000  190200.000000  99999.000000
#
#                TSH           T3         fnlwgt  hours-per-week  education-num
# count  2038.000000  1804.000000    2277.000000     2276.000000    2056.000000
# mean      4.691447     2.020926  187889.619675       38.293058      10.050584
# ...

# %%
np.unique(data_other[['name', 'address']].values)
len(names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2b4dd26eb494> in <module>()
# ----> 1 np.unique(data_other[['name', 'address']].values)
#       2 len(names)
#
# NameError: name 'np' is not defined
